# %%
import pandas as pd
df=pd.read_csv("emp.csv")
df.sample(5)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 301      James    Male  7/11/2015         8:52 PM   72257   13.023
# 584       Jack    Male  5/30/2012         3:17 AM   70367   18.266
# 334       Todd    Male  5/23/2011         4:14 PM   85074    1.844
# 67      Rachel  Female  8/16/1999         6:53 AM   51178    9.735
# 147     Philip    Male  7/17/2008         1:30 PM   89227    3.996
#
#     Senior Management             Team
# 301             False      Engineering
# 584              True            Legal
# 334             False  Client Services
# 67               True          Finance
# 147             False            Legal

# %% [markdown]
# <img src="dow.jpeg">

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.isnull().all()
# Out:
# First Name           False
# Gender               False
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management    False
# Team                 False
# dtype: bool

# %%
df.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
df['Salary'].isnull().any()
# Out:
# False

# %%
df['Bonus %'].isnull().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df['First Name']=df['First Name'].fillna("Himanshu")
df['First Name'].sample(10)
# Out:
# 795      Theresa
# 459      Charles
# 324         Ruby
# 651      Deborah
# 971      Patrick
# 695        Sarah
# 644    Katherine
# 874      Melissa
# 303         Joan
# 863      Phillip
# Name: First Name, dtype: object

# %%
df['First Name']=df['First Name'].replace(to_replace='NaN',value='PRAJAPATI')
df['First Name'].sample(10)
# Out:
# 779       Doris
# 709    Himanshu
# 431     Charles
# 359       Sarah
# 139    Himanshu
# 455        Ruth
# 2         Maria
# 636     Marilyn
# 653       Debra
# 870     Cynthia
# Name: First Name, dtype: object

# %%
df.sample(10)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 986      Donna  Female  11/26/1982         7:04 AM   82871   17.999
# 248     Justin    Male   12/6/1992         5:58 PM   82782    4.366
# 819    Kenneth    Male  12/14/1985         6:55 AM   47232   17.862
# 47       Kathy  Female   6/22/2005         4:51 AM   66820    9.000
# 702      Debra  Female   3/17/2011         1:12 PM   84693    6.976
# 462      Craig    Male   4/14/1996         9:17 AM  125556    7.996
# 701      Robin     NaN   9/16/2005         1:26 AM   93201   11.712
# 672     Robert    Male   11/5/1982        12:41 PM  111580   10.982
# 229     Jeremy    Male    6/8/2000        12:15 AM   49542    1.679
# 733   Himanshu    Male   6/17/2009         1:00 PM  136681    3.655
#
#     Senior Management                  Team
# 986             False             Marketing
# 248              True          Distribution
# 819              True                 Legal
# ...

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x='Bonus %', y='Salary',data= df,hue='Team')
# Out:
# <Axes: xlabel='Bonus %', ylabel='Salary'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\240 g8\AppData\Roaming\Python\Python311\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# C:\Users\240 g8\AppData\Roaming\Python\Python311\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)

# %%
import scipy
import pandas as pd
from ydata_profiling import ProfileReport
df=pd.read_csv('emp.csv')
profile = ProfileReport(df, title="Profiling Report")
profile.to_file('a.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
# df.drop('First Name','Gender',	'Start Date',	'Last Login Time',	'Salary',	'Bonus %','	Senior Management',"Team")
x=df[['Salary']]
y=df['Bonus %']

# %%
x
# Out:
#      Salary
# 0     97308
# 1     61933
# 2    130590
# 3    138705
# 4    101004
# ..      ...
# 995  132483
# 996   42392
# 997   96914
# 998   60500
# 999  129949
#
# [1000 rows x 1 columns]

# %%
y
# Out:
# 0       6.945
# 1       4.170
# 2      11.858
# 3       9.340
# 4       1.389
#         ...
# 995    16.655
# 996    19.675
# 997     1.421
# 998    11.985
# 999    10.169
# Name: Bonus %, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
x_train.shape
# Out:
# (750, 1)

# %%
y_test.shape
# Out:
# (250,)

# %%
from sklearn.linear_model import LinearRegression

# %%
mukesh=LinearRegression()

# %%
mukesh.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mukesh.predict(x_test)

# %%
mukesh.predict([[130590]])
# Out:
# C:\Users\240 g8\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.22778832])

# %%
mukesh.predict([[130590]])
# Out:
# C:\Users\240 g8\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.22778832])

# %%
# slope(m)
mukesh.coef_
# Out:
# array([-2.67260036e-07])

# %%
# intercept(c)
mukesh.intercept_
# Out:
# 10.262689806931368

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_score(y_test,y_pred)
# Out:
# -5.2404544705009215e-05

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 34.9253431018517

# %%
mukesh.predict(df[["Salary"]])
# Out:
# array([10.23668327, 10.24613759, 10.22778832, 10.2256195 , 10.23569547,
#        10.23191134, 10.24519069, 10.25042097, 10.23714777, 10.22531296,
#        10.24578801, 10.23529352, 10.232541  , 10.23333637, 10.25161829,
#        10.24681082, 10.23853752, 10.23282697, 10.22716026, 10.241038  ,
#        10.24539434, 10.23580024, 10.23841832, 10.22907063, 10.23651169,
#        10.25278087, 10.25264136, 10.229986  , 10.22954742, 10.24143488,
#        10.23094466, 10.23899533, 10.22999321, 10.23086395, 10.23710393,
#        10.23992406, 10.22473033, 10.24734186, 10.25284288, 10.23003785,
#        10.23615543, 10.2448951 , 10.230106  , 10.24303978, 10.22389808,
#        10.23916825, 10.23200942, 10.24483149, 10.23767935, 10.23233174,
#        10.23730652, 10.25169847, 10.24950346, 10.25190827, 10.24032629,
#        10.23529886, 10.22787224, 10.24539407, 10.24326802, 10.24482321,
#        10.24962988, 10.23412986, 10.24715879, 10.25328145, 10.24188789,
# ...

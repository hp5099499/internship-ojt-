# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("pic1.jpg")

# %%
plt.imshow(img)

# %%
img.size
# Out:
# 3072000

# %%
img.shape
# Out:
# (800, 1280, 3)

# %%
a=img[100,200]

# %%
a
# Out:
# array([ 9, 11, 19], dtype=uint8)

# %%
img1=cv2.imread("pic1.jpg")

# %%
b,g,r=cv2.split(img1)

# %%
b.shape
# Out:
# (800, 1280)

# %%
plt.imshow(img1)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_rgb=cv2.resize(img_rgb,(1200,800))

# %%
plt.imshow(img_rgb)

# %%
imgf1=cv2.flip(img_rgb,90)

# %%
plt.imshow(imgf1)

# %%
img_rgb.shape
# Out:
# (800, 1200, 3)

# %%
x_offset=588-230

# %%
y_offset=190-100

# %%
# region of interest
rows,cols,channels=img_rgb.shape
roi=img_rgb[0:x_offset,0:cols]

plt.imshow(roi)

# %%
roi=img_rgb[x_offset:rows,y_offset:cols]

plt.imshow(roi)

# %%
roi=img_rgb[300:380,780:950]
plt.imshow(roi)

# %%
f = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img_rgb, text="Himanshu", org=(100, 300), fontFace=f,fontScale=2,color=(255,302,130), thickness=3)
plt.imshow(img_rgb)

# %% [markdown]
# ##

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_inv=cv2.bitwise_not(img_gray)

# %%
plt.imshow(img_inv,cmap='gray')

# %%
img_sm=cv2.GaussianBlur(img_inv,(25,25),sigmaX=0,sigmaY=0)

# %%
plt.imshow(img_sm,cmap='gray')

# %%
img_pencil=cv2.divide(img_gray,255-img_sm,scale=255)

# %%
plt.imshow(img_pencil,cmap='gray')

# %%
import numpy as np

# %%
plt.imshow(img1)

# %%
face_cas=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
def detect_face(image):
    face_img=image.copy()
    face_cont=face_cas.detectMultiScale(face_img)
    for (x,y,w,h) in face_cont:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
        return face_img

# %%
res=detect_face(img)
plt.imshow(res,cmap='gray')

# %%
img_nh=cv2.imread("google.png")

# %%
plt.imshow(img_nh,cmap='gray')

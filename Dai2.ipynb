# %%
import pandas as pd
df =pd.read_csv('dia.csv')

# %%
x = df.drop('Outcome', axis='columns')

# %%
y = df.Outcome

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
#Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI,Diab,Age
model.predict([[2,90,90,3,40, 20, 0.1,21]])
# Out:
# C:\Users\suraj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.7875647668393783

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
for i in range(3):
    tree = model.estimators_[i]
    dot_data = export_graphviz(tree)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
for i in range(3):
    tree = model.estimators_[i]
      graph = grap
